# %% [markdown]
# # Goals
#
# ### - Identify what is driving log error
# ### - Build a model to accurately predict the log error

# %% [markdown]
# # Hypotheses
# What we think causes log error:
# - Location: certain geographic areas may be harder to accurately predict than others. Log error may differ by County.
# - Price: higher prices may have more variance which makes them harder to predict
# - Age of Property: newer homes may be similarily built, thus easier to predict price. Older property values may have more variance, thus making them harder to predict
# - Amenities: fireplace, pool, hot tub, and garage are nice amenities that not all properties include. These amenities may be driving log error by making property values harder to predict.
# - Data density: geographic areas with more data points (higher data density) will have lower log errors. Geogrphaic areas with less data points (lower data density) will have higher log errors. The more data we have in a given geographic area, the lower we would expect those log errors to be.

# %% [markdown]
# ## Set up Environment

# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set(style="white", palette="muted")
#import acquire
import prep
# %matplotlib inline
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
import scipy
from sklearn.cluster import KMeans
from sklearn.cluster import dbscan
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# # Acquire

# %% [markdown]
# ### Here we acquire our data from the SQL database. We have already chosen to filter on the following conditions:
# - Only include properties containing latitude and longitude values.
# - Only include properties with a transaction in 2017 (including the most recent transaction date to avoid duplicates).
# - Only include single unit properties.
#   - Single unit property: a free standing property in which the owner also owns the land beneath the property. A single unit property is built for the use of one family (i.e. does not include duplexes, triplexes, etc.)

# %%
data = pd.read_csv('query_result.csv')

# %% [markdown]
# Preview data:

# %%
data.shape
# Out:
# (52357, 61)

# %%
data.head(5)
# Out:
#    parcelid       id  airconditioningtypeid  architecturalstyletypeid  \
# 0  14297519  1727539                    NaN                       NaN
# 1  17052889  1387261                    NaN                       NaN
# 2  14186244    11677                    NaN                       NaN
# 3  12177905  2288172                    NaN                       NaN
# 4  12095076   781532                    1.0                       NaN
#
#    basementsqft  bathroomcnt  bedroomcnt  buildingclasstypeid  \
# 0           NaN          3.5           4                  NaN
# 1           NaN          1.0           2                  NaN
# 2           NaN          2.0           3                  NaN
# 3           NaN          3.0           4                  NaN
# 4           NaN          3.0           4                  NaN
#
#    buildingqualitytypeid  calculatedbathnbr  ...  structuretaxvaluedollarcnt  \
# 0                    NaN                3.5  ...                    485713.0
# 1                    NaN                1.0  ...                     88000.0
# 2                    NaN                2.0  ...                     85289.0
# 3                    8.0                3.0  ...                    108918.0
# 4                    9.0                3.0  ...                    276684.0
#
#    taxvaluedollarcnt  assessmentyear  landtaxvaluedollarcnt  taxamount  \
# 0          1023282.0            2016               537569.0   11013.72
# 1           464000.0            2016               376000.0    5672.48
# 2           564778.0            2016               479489.0    6488.30
# 3           145143.0            2016                36225.0    1777.51
# 4           773303.0            2016               496619.0    9516.26
#
#    taxdelinquencyflag  taxdelinquencyyear  censustractandblock  logerror  \
# 0                 NaN                 NaN         6.059063e+13  0.025595
# 1                 NaN                 NaN         6.111001e+13  0.055619
# 2                 NaN                 NaN         6.059022e+13  0.005383
# 3                 NaN                 NaN         6.037300e+13 -0.103410
# 4                 NaN                 NaN         6.037461e+13 -0.001011
#
#    transactiondate
# 0       2017-01-01
# 1       2017-01-01
# 2       2017-01-01
# 3       2017-01-01
# 4       2017-01-01
#
# [5 rows x 61 columns]

# %%
data.columns
# Out:
# Index(['parcelid', 'id', 'airconditioningtypeid', 'architecturalstyletypeid',
#        'basementsqft', 'bathroomcnt', 'bedroomcnt', 'buildingclasstypeid',
#        'buildingqualitytypeid', 'calculatedbathnbr', 'decktypeid',
#        'finishedfloor1squarefeet', 'calculatedfinishedsquarefeet',
#        'finishedsquarefeet12', 'finishedsquarefeet13', 'finishedsquarefeet15',
#        'finishedsquarefeet50', 'finishedsquarefeet6', 'fips', 'fireplacecnt',
#        'fullbathcnt', 'garagecarcnt', 'garagetotalsqft', 'hashottuborspa',
#        'heatingorsystemtypeid', 'latitude', 'longitude', 'lotsizesquarefeet',
#        'poolcnt', 'poolsizesum', 'pooltypeid10', 'pooltypeid2', 'pooltypeid7',
#        'propertycountylandusecode', 'propertylandusetypeid',
#        'propertyzoningdesc', 'rawcensustractandblock', 'regionidcity',
#        'regionidcounty', 'regionidneighborhood', 'regionidzip', 'roomcnt',
#        'storytypeid', 'threequarterbathnbr', 'typeconstructiontypeid',
#        'unitcnt', 'yardbuildingsqft17', 'yardbuildingsqft26', 'yearbuilt',
#        'numberofstories', 'fireplaceflag', 'structuretaxvaluedollarcnt',
#        'taxvaluedollarcnt', 'assessmentyear', 'landtaxvaluedollarcnt',
#        'taxamount', 'taxdelinquencyflag', 'taxdelinquencyyear',
#        'censustractandblock', 'logerror', 'transactiondate'],
#       dtype='object')

# %% [markdown]
# # Prepare
# ### There are several rows and columns that are missing data. We need to treat null values by dropping columns, dropping rows, or imputing missing values.

# %% [markdown]
# ### Preview nulls

# %% [markdown]
# This function shows the amount of rows that have null values for each column. We use this to check if there are any columns that are droppable due to a large portion of nulls.

# %%
prep.nulls_by_col(data)
# Out:
#                               num_rows_missing  pct_rows_missing
# parcelid                                     0          0.000000
# id                                           0          0.000000
# airconditioningtypeid                    38738          0.739882
# architecturalstyletypeid                 52287          0.998663
# basementsqft                             52310          0.999102
# bathroomcnt                                  0          0.000000
# bedroomcnt                                   0          0.000000
# buildingclasstypeid                      52357          1.000000
# buildingqualitytypeid                    18692          0.357011
# calculatedbathnbr                          162          0.003094
# decktypeid                               51968          0.992570
# finishedfloor1squarefeet                 47986          0.916515
# calculatedfinishedsquarefeet               107          0.002044
# finishedsquarefeet12                       273          0.005214
# finishedsquarefeet13                     52357          1.000000
# finishedsquarefeet15                     52357          1.000000
# finishedsquarefeet50                     47986          0.916515
# finishedsquarefeet6                      52191          0.996829
# fips                                         0          0.000000
# fireplacecnt                             45124          0.861852
# fullbathcnt                                162          0.003094
# garagecarcnt                             34373          0.656512
# garagetotalsqft                          34373          0.656512
# hashottuborspa                           50843          0.971083
# heatingorsystemtypeid                    18497          0.353286
# latitude                                     0          0.000000
# longitude                                    0          0.000000
# lotsizesquarefeet                          375          0.007162
# poolcnt                                  41277          0.788376
# poolsizesum                              51492          0.983479
# ...                                        ...               ...
# pooltypeid2                              51286          0.979544
# pooltypeid7                              42364          0.809137
# propertycountylandusecode                    0          0.000000
# propertylandusetypeid                        0          0.000000
# propertyzoningdesc                       18559          0.354470
# rawcensustractandblock                       0          0.000000
# regionidcity                              1036          0.019787
# regionidcounty                               0          0.000000
# regionidneighborhood                     33357          0.637107
# regionidzip                                 26          0.000497
# roomcnt                                      0          0.000000
# storytypeid                              52310          0.999102
# threequarterbathnbr                      45640          0.871708
# typeconstructiontypeid                   52281          0.998548
# unitcnt                                  18582          0.354910
# yardbuildingsqft17                       50422          0.963042
# yardbuildingsqft26                       52294          0.998797
# yearbuilt                                  140          0.002674
# numberofstories                          37824          0.722425
# fireplaceflag                            52276          0.998453
# structuretaxvaluedollarcnt                  82          0.001566
# taxvaluedollarcnt                            1          0.000019
# assessmentyear                               0          0.000000
# landtaxvaluedollarcnt                        1          0.000019
# taxamount                                    4          0.000076
# taxdelinquencyflag                       50288          0.960483
# taxdelinquencyyear                       50288          0.960483
# censustractandblock                        125          0.002387
# logerror                                     0          0.000000
# transactiondate                              0          0.000000
#
# [61 rows x 2 columns]

# %% [markdown]
# This function shows the amount of rows that are missing a certain number of columns. We use this to check if there are any rows that are missing so many columns, they are not worth keeping.
# We will drop columns first, and then come back and check these rows to see how they were affected.

# %%
prep.nulls_by_row(data)
# Out:
#    num_cols_missing    pct_cols_missing  num_rows
# 0                19  31.147540983606557         2
# 1                20   32.78688524590164        10
# 2                21   34.42622950819672        83
# 3                22    36.0655737704918       261
# 4                23  37.704918032786885       480
# 5                24   39.34426229508197       534
# 6                25   40.98360655737705      2910
# 7                26   42.62295081967213      5921
# 8                27   44.26229508196721      7934
# 9                28   45.90163934426229     15854
# 10               29  47.540983606557376     12523
# 11               30   49.18032786885246      4405
# 12               31   50.81967213114754      1057
# 13               32  52.459016393442624       227
# 14               33   54.09836065573771        36
# 15               34   55.73770491803278        16
# 16               35  57.377049180327866         8
# 17               36   59.01639344262295        12
# 18               37   60.65573770491803        22
# 19               38  62.295081967213115        51
# 20               39  63.934426229508205         7
# 21               40   65.57377049180327         1
# 22               41   67.21311475409836         1
# 23               42   68.85245901639344         2

# %% [markdown]
# ### Run data through our prep function to acheive the following:
# - fills nulls in taxdelinquencyflag with 'N'
# - fills nulls with zero for fireplacecnt, garagecarcnt, poolcnt, and taxdelinquencyyear
# - drops 28 columns due to excess nulls and irrelevency
# - encodes the fips columns
# - data shape transformed from 52357 rows x 61 columns to 46649 rows x 33 columns

# %%
data = prep.prep_zillow(data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52357 entries, 0 to 52356
# Data columns (total 61 columns):
# parcelid                        52357 non-null int64
# id                              52357 non-null int64
# airconditioningtypeid           13619 non-null float64
# architecturalstyletypeid        70 non-null float64
# basementsqft                    47 non-null float64
# bathroomcnt                     52357 non-null float64
# bedroomcnt                      52357 non-null int64
# buildingclasstypeid             0 non-null float64
# buildingqualitytypeid           33665 non-null float64
# calculatedbathnbr               52195 non-null float64
# decktypeid                      389 non-null float64
# finishedfloor1squarefeet        4371 non-null float64
# calculatedfinishedsquarefeet    52250 non-null float64
# finishedsquarefeet12            52084 non-null float64
# finishedsquarefeet13            0 non-null float64
# finishedsquarefeet15            0 non-null float64
# finishedsquarefeet50            4371 non-null float64
# finishedsquarefeet6             166 non-null float64
# fips                            52357 non-null int64
# fireplacecnt                    7233 non-null float64
# fullbathcnt                     52195 non-null float64
# garagecarcnt                    17984 non-null float64
# garagetotalsqft                 17984 non-null float64
# hashottuborspa                  1514 non-null float64
# heatingorsystemtypeid           33860 non-null float64
# latitude                        52357 non-null int64
# longitude                       52357 non-null int64
# lotsizesquarefeet               51982 non-null float64
# poolcnt                         11080 non-null float64
# poolsizesum                     865 non-null float64
# pooltypeid10                    443 non-null float64
# pooltypeid2                     1071 non-null float64
# pooltypeid7                     9993 non-null float64
# propertycountylandusecode       52357 non-null object
# propertylandusetypeid           52357 non-null int64
# propertyzoningdesc              33798 non-null object
# rawcensustractandblock          52357 non-null float64
# regionidcity                    51321 non-null float64
# regionidcounty                  52357 non-null int64
# regionidneighborhood            19000 non-null float64
# regionidzip                     52331 non-null float64
# roomcnt                         52357 non-null int64
# storytypeid                     47 non-null float64
# threequarterbathnbr             6717 non-null float64
# typeconstructiontypeid          76 non-null float64
# unitcnt                         33775 non-null float64
# yardbuildingsqft17              1935 non-null float64
# yardbuildingsqft26              63 non-null float64
# yearbuilt                       52217 non-null float64
# numberofstories                 14533 non-null float64
# fireplaceflag                   81 non-null float64
# structuretaxvaluedollarcnt      52275 non-null float64
# taxvaluedollarcnt               52356 non-null float64
# assessmentyear                  52357 non-null int64
# landtaxvaluedollarcnt           52356 non-null float64
# taxamount                       52353 non-null float64
# taxdelinquencyflag              2069 non-null object
# taxdelinquencyyear              2069 non-null float64
# censustractandblock             52232 non-null float64
# logerror                        52357 non-null float64
# transactiondate                 52357 non-null object
# dtypes: float64(47), int64(10), object(4)
# memory usage: 24.4+ MB

# %%
data.shape
# Out:
# (46756, 21)

# %%
data.columns
# Out:
# Index(['parcelid', 'bathroomcnt', 'bedroomcnt', 'calculatedfinishedsquarefeet',
#        'fips', 'fireplacecnt', 'garagecarcnt', 'latitude', 'longitude',
#        'lotsizesquarefeet', 'poolcnt', 'propertylandusetypeid', 'regionidcity',
#        'regionidcounty', 'regionidzip', 'roomcnt', 'yearbuilt',
#        'taxvaluedollarcnt', 'taxdelinquencyflag', 'taxdelinquencyyear',
#        'logerror'],
#       dtype='object')

# %%
data.dtypes
# Out:
# parcelid                          int64
# bathroomcnt                     float64
# bedroomcnt                        int64
# calculatedfinishedsquarefeet    float64
# fips                              int64
# fireplacecnt                    float64
# garagecarcnt                    float64
# latitude                          int64
# longitude                         int64
# lotsizesquarefeet               float64
# poolcnt                         float64
# propertylandusetypeid             int64
# regionidcity                    float64
# regionidcounty                    int64
# regionidzip                     float64
# roomcnt                           int64
# yearbuilt                       float64
# taxvaluedollarcnt               float64
# taxdelinquencyflag                int64
# taxdelinquencyyear              float64
# logerror                        float64
# dtype: object

# %%
X = data.drop(columns = ['poor_people', 'log_me'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-db8d6b79dfa0> in <module>
# ----> 1 X = data.drop(columns = ['poor_people', 'log_me'])
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# -> 3780                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3781
#    3782         if inplace:
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3810                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3811             else:
# -> 3812                 new_axis = axis.drop(labels, errors=errors)
#    3813             result = self.reindex(**{axis_name: new_axis})
#    3814
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    4963             if errors != 'ignore':
#    4964                 raise KeyError(
# -> 4965                     '{} not found in axis'.format(labels[mask]))
#    4966             indexer = indexer[~mask]
#    4967         return self.delete(indexer)
#
# KeyError: "['poor_people' 'log_me'] not found in axis"

# %%
sns.heatmap(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-7277d518b835> in <module>
# ----> 1 sns.heatmap(X)
#
# NameError: name 'X' is not defined

# %%
data.head()
# Out:
#    parcelid  bathroomcnt  bedroomcnt  calculatedfinishedsquarefeet  fips  \
# 1  17052889          1.0           2                        1465.0     2
# 2  14186244          2.0           3                        1243.0     1
# 3  12177905          3.0           4                        2376.0     0
# 4  12095076          3.0           4                        2962.0     0
# 5  12069064          1.0           2                         738.0     0
#
#    fireplacecnt  garagecarcnt  latitude  longitude  lotsizesquarefeet  ...  \
# 1           1.0           1.0  34449266 -119281531            12647.0  ...
# 2           0.0           2.0  33886168 -117823170             8432.0  ...
# 3           0.0           0.0  34245180 -118240722            13038.0  ...
# 4           0.0           0.0  34145202 -118179824            63000.0  ...
# 5           0.0           0.0  34149214 -118239357             4214.0  ...
#
#    propertylandusetypeid  regionidcity  regionidcounty  regionidzip  roomcnt  \
# 1                    261       13091.0            2061      97099.0        5
# 2                    261       21412.0            1286      97078.0        6
# 3                    261      396551.0            3101      96330.0        0
# 4                    261       47019.0            3101      96293.0        0
# 5                    261       45457.0            3101      96325.0        0
#
#    yearbuilt  taxvaluedollarcnt  taxdelinquencyflag  taxdelinquencyyear  \
# 1     1967.0           464000.0                   0                 0.0
# 2     1962.0           564778.0                   0                 0.0
# 3     1970.0           145143.0                   0                 0.0
# 4     1950.0           773303.0                   0                 0.0
# 5     1922.0           218552.0                   0                 0.0
#
#    logerror
# 1  0.055619
# 2  0.005383
# 3 -0.103410
# 4 -0.001011
# 5  0.101723
#
# [5 rows x 21 columns]

# %% [markdown]
# # Explore
# To do:
#
# - Check our hypotheses
# - t tests
# - chi square test
# - clustering

# %%
sns.scatterplot(x='logerror',y='yearbuilt', data = data)

# %%
data.corr()
# Out:
#                               parcelid  bathroomcnt  bedroomcnt  \
# parcelid                      1.000000     0.067556    0.074868
# bathroomcnt                   0.067556     1.000000    0.624234
# bedroomcnt                    0.074868     0.624234    1.000000
# calculatedfinishedsquarefeet  0.072101     0.799004    0.629117
# fips                          0.529092     0.158046    0.156628
# fireplacecnt                  0.339291     0.160012    0.151163
# garagecarcnt                  0.445554     0.220746    0.199923
# latitude                     -0.169301     0.049647    0.048408
# longitude                    -0.072063     0.005006   -0.007811
# lotsizesquarefeet            -0.013919     0.014869    0.001828
# poolcnt                      -0.008818     0.254149    0.215936
# propertylandusetypeid         0.006671     0.043571    0.060512
# regionidcity                 -0.027347    -0.060170   -0.049474
# regionidcounty               -0.387681    -0.161191   -0.140770
# regionidzip                   0.028324     0.033891    0.021056
# roomcnt                       0.424093     0.132278    0.203176
# yearbuilt                     0.164711     0.540522    0.371836
# taxvaluedollarcnt             0.088846     0.399990    0.236200
# taxdelinquencyflag           -0.044317    -0.060032   -0.045336
# taxdelinquencyyear           -0.044091    -0.057925   -0.044308
# logerror                      0.007230     0.027636    0.039754
#
#                               calculatedfinishedsquarefeet      fips  \
# parcelid                                          0.072101  0.529092
# bathroomcnt                                       0.799004  0.158046
# bedroomcnt                                        0.629117  0.156628
# calculatedfinishedsquarefeet                      1.000000  0.162633
# fips                                              0.162633  1.000000
# fireplacecnt                                      0.199747  0.620868
# garagecarcnt                                      0.227626  0.872777
# latitude                                          0.031712 -0.239963
# longitude                                        -0.002917 -0.192006
# lotsizesquarefeet                                 0.025447 -0.016702
# poolcnt                                           0.301279  0.019981
# propertylandusetypeid                            -0.004926  0.013060
# regionidcity                                     -0.058061 -0.062120
# regionidcounty                                   -0.158700 -0.793113
# regionidzip                                       0.029220  0.054662
# roomcnt                                           0.149093  0.831342
# yearbuilt                                         0.475770  0.327296
# taxvaluedollarcnt                                 0.460109  0.188679
# taxdelinquencyflag                               -0.049351 -0.080075
# taxdelinquencyyear                               -0.047788 -0.079558
# logerror                                          0.027443  0.012689
#
#                               fireplacecnt  garagecarcnt  latitude  longitude  \
# parcelid                          0.339291      0.445554 -0.169301  -0.072063
# bathroomcnt                       0.160012      0.220746  0.049647   0.005006
# bedroomcnt                        0.151163      0.199923  0.048408  -0.007811
# calculatedfinishedsquarefeet      0.199747      0.227626  0.031712  -0.002917
# fips                              0.620868      0.872777 -0.239963  -0.192006
# fireplacecnt                      1.000000      0.534191 -0.066052  -0.224796
# garagecarcnt                      0.534191      1.000000 -0.435377   0.131245
# latitude                         -0.066052     -0.435377  1.000000  -0.531718
# longitude                        -0.224796      0.131245 -0.531718   1.000000
# lotsizesquarefeet                -0.003863     -0.019327  0.056274  -0.010717
# poolcnt                           0.083578      0.055755  0.021388   0.001247
# propertylandusetypeid             0.008208      0.014942 -0.007823  -0.002308
# regionidcity                     -0.027174     -0.070075 -0.017105  -0.006678
# regionidcounty                   -0.409872     -0.907746  0.572667  -0.341575
# regionidzip                       0.029183      0.055704  0.018068   0.028224
# roomcnt                           0.619804      0.810130 -0.306809  -0.018859
# yearbuilt                         0.203245      0.373620  0.111885   0.078307
# taxvaluedollarcnt                 0.165260      0.233785 -0.175405   0.003146
# taxdelinquencyflag               -0.051517     -0.081790  0.035346   0.004240
# taxdelinquencyyear               -0.050704     -0.080438  0.034828   0.005001
# logerror                          0.000632      0.013678 -0.011473   0.013516
#
#                               lotsizesquarefeet  ...  propertylandusetypeid  \
# parcelid                              -0.013919  ...               0.006671
# bathroomcnt                            0.014869  ...               0.043571
# bedroomcnt                             0.001828  ...               0.060512
# calculatedfinishedsquarefeet           0.025447  ...              -0.004926
# fips                                  -0.016702  ...               0.013060
# fireplacecnt                          -0.003863  ...               0.008208
# garagecarcnt                          -0.019327  ...               0.014942
# latitude                               0.056274  ...              -0.007823
# longitude                             -0.010717  ...              -0.002308
# lotsizesquarefeet                      1.000000  ...               0.000077
# poolcnt                                0.007824  ...               0.010279
# propertylandusetypeid                  0.000077  ...               1.000000
# regionidcity                          -0.009244  ...              -0.005530
# regionidcounty                         0.024580  ...              -0.013132
# regionidzip                            0.004698  ...               0.000873
# roomcnt                               -0.015408  ...               0.011531
# yearbuilt                              0.029830  ...              -0.002325
# taxvaluedollarcnt                     -0.001680  ...              -0.006501
# taxdelinquencyflag                    -0.000874  ...              -0.000707
# taxdelinquencyyear                    -0.000714  ...              -0.000666
# logerror                               0.008460  ...               0.009699
#
#                               regionidcity  regionidcounty  regionidzip  \
# parcelid                         -0.027347       -0.387681     0.028324
# bathroomcnt                      -0.060170       -0.161191     0.033891
# bedroomcnt                       -0.049474       -0.140770     0.021056
# calculatedfinishedsquarefeet     -0.058061       -0.158700     0.029220
# fips                             -0.062120       -0.793113     0.054662
# fireplacecnt                     -0.027174       -0.409872     0.029183
# garagecarcnt                     -0.070075       -0.907746     0.055704
# latitude                         -0.017105        0.572667     0.018068
# longitude                        -0.006678       -0.341575     0.028224
# lotsizesquarefeet                -0.009244        0.024580     0.004698
# poolcnt                          -0.029600       -0.038261     0.019649
# propertylandusetypeid            -0.005530       -0.013132     0.000873
# regionidcity                      1.000000        0.074872    -0.014707
# regionidcounty                    0.074872        1.000000    -0.057067
# regionidzip                      -0.014707       -0.057067     1.000000
# roomcnt                          -0.057591       -0.785277     0.048056
# yearbuilt                        -0.096154       -0.324130     0.063755
# taxvaluedollarcnt                -0.004984       -0.203042     0.013325
# taxdelinquencyflag                0.005942        0.076648    -0.007565
# taxdelinquencyyear                0.005128        0.075335    -0.007408
# logerror                          0.004214       -0.017184     0.001032
#
#                                roomcnt  yearbuilt  taxvaluedollarcnt  \
# parcelid                      0.424093   0.164711           0.088846
# bathroomcnt                   0.132278   0.540522           0.399990
# bedroomcnt                    0.203176   0.371836           0.236200
# calculatedfinishedsquarefeet  0.149093   0.475770           0.460109
# fips                          0.831342   0.327296           0.188679
# fireplacecnt                  0.619804   0.203245           0.165260
# garagecarcnt                  0.810130   0.373620           0.233785
# latitude                     -0.306809   0.111885          -0.175405
# longitude                    -0.018859   0.078307           0.003146
# lotsizesquarefeet            -0.015408   0.029830          -0.001680
# poolcnt                       0.082071   0.094210           0.187293
# propertylandusetypeid         0.011531  -0.002325          -0.006501
# regionidcity                 -0.057591  -0.096154          -0.004984
# regionidcounty               -0.785277  -0.324130          -0.203042
# regionidzip                   0.048056   0.063755           0.013325
# roomcnt                       1.000000   0.200796           0.115580
# yearbuilt                     0.200796   1.000000           0.266682
# taxvaluedollarcnt             0.115580   0.266682           1.000000
# taxdelinquencyflag           -0.071583  -0.068216          -0.045699
# taxdelinquencyyear           -0.070638  -0.065508          -0.041961
# logerror                      0.014843   0.015641          -0.028880
#
#                               taxdelinquencyflag  taxdelinquencyyear  logerror
# parcelid                               -0.044317           -0.044091  0.007230
# bathroomcnt                            -0.060032           -0.057925  0.027636
# bedroomcnt                             -0.045336           -0.044308  0.039754
# calculatedfinishedsquarefeet           -0.049351           -0.047788  0.027443
# fips                                   -0.080075           -0.079558  0.012689
# fireplacecnt                           -0.051517           -0.050704  0.000632
# garagecarcnt                           -0.081790           -0.080438  0.013678
# latitude                                0.035346            0.034828 -0.011473
# longitude                               0.004240            0.005001  0.013516
# lotsizesquarefeet                      -0.000874           -0.000714  0.008460
# poolcnt                                -0.020085           -0.019154 -0.036842
# propertylandusetypeid                  -0.000707           -0.000666  0.009699
# regionidcity                            0.005942            0.005128  0.004214
# regionidcounty                          0.076648            0.075335 -0.017184
# regionidzip                            -0.007565           -0.007408  0.001032
# roomcnt                                -0.071583           -0.070638  0.014843
# yearbuilt                              -0.068216           -0.065508  0.015641
# taxvaluedollarcnt                      -0.045699           -0.041961 -0.028880
# taxdelinquencyflag                      1.000000            0.983964  0.025705
# taxdelinquencyyear                      0.983964            1.000000  0.020211
# logerror                                0.025705            0.020211  1.000000
#
# [21 rows x 21 columns]

# %%
X = data[['latitude', 'longitude', 'logerror']]
# Create (using the default 8 clusters)
kmeans = KMeans(n_clusters=5)
# Fit
kmeans.fit(X)
kmeans.predict(X)
# Out:
# array([4, 2, 1, ..., 0, 0, 0], dtype=int32)

# %%
# Check for the coordinates of the centroids
centers = pd.DataFrame(kmeans.cluster_centers_, columns=X.columns)
centers
# Out:
#        latitude     longitude  logerror
# 0  3.396361e+07 -1.181461e+08  0.011899
# 1  3.422194e+07 -1.184821e+08  0.011340
# 2  3.375941e+07 -1.178167e+08  0.016904
# 3  3.462766e+07 -1.181263e+08  0.011080
# 4  3.424520e+07 -1.190213e+08  0.014233

# %%
# Visualize the data
fig = plt.figure(figsize=(12, 9))
ax = Axes3D(fig)

ax.scatter(X.latitude, X.longitude, X.logerror, c=kmeans.labels_)
ax.scatter(centers.latitude, centers.longitude, centers.logerror, c='orange', s=2000, alpha=.3)
ax.set(xlabel='latitude', ylabel='longitude', zlabel='logerror')
# Out:
# [Text(0.5, 0, 'logerror'), Text(0.5, 0, 'longitude'), Text(0.5, 0, 'latitude')]

# %%
X = data[['latitude', 'longitude', 'taxvaluedollarcnt']]
# Create (using the default 8 clusters)
kmeans = KMeans(n_clusters=8)
# Fit
kmeans.fit(X)
kmeans.predict(X)
# Out:
# array([7, 0, 2, ..., 2, 0, 5], dtype=int32)

# %%
# Check for the coordinates of the centroids
centers = pd.DataFrame(kmeans.cluster_centers_, columns=X.columns)
centers
# Out:
#        latitude     longitude  taxvaluedollarcnt
# 0  3.392230e+07 -1.179778e+08      506878.598709
# 1  3.425867e+07 -1.185114e+08      308058.723913
# 2  3.396340e+07 -1.182294e+08      194966.421451
# 3  3.363016e+07 -1.177276e+08      638206.232877
# 4  3.462826e+07 -1.181254e+08      197106.520892
# 5  3.386324e+07 -1.178928e+08      185206.624665
# 6  3.411167e+07 -1.183956e+08      713999.779095
# 7  3.424644e+07 -1.190415e+08      428740.568944

# %%
# Visualize the data
fig = plt.figure(figsize=(12, 9))
ax = Axes3D(fig)

ax.scatter(X.latitude, X.longitude, X.taxvaluedollarcnt, c=kmeans.labels_)
ax.scatter(centers.latitude, centers.longitude, centers.taxvaluedollarcnt, c='orange', s=2000, alpha=.3)
ax.set(xlabel='latitude', ylabel='longitude', zlabel='taxvaluedollarcnt')
# Out:
# [Text(0.5, 0, 'taxvaluedollarcnt'),
#  Text(0.5, 0, 'longitude'),
#  Text(0.5, 0, 'latitude')]

# %%
sns.scatterplot(x='logerror',y='lotsizesquarefeet', data = data)

# %%
sns.scatterplot(x='logerror',y='calculatedfinishedsquarefeet', data = data, alpha = .5)

# %%
#scipy.stats.ttest_ind(X.logerror,X.calculatedfinishedsquarefeet)

# %%
print(data.groupby('fips')['logerror'].mean())
print(data['fips'].value_counts())

g = sns.FacetGrid(data, col = 'fips')
g = g.map(plt.scatter, 'logerror', 'taxvaluedollarcnt', alpha = .3)
# Out:
# fips
# 0    0.011911
# 1    0.016421
# 2    0.013860
# Name: logerror, dtype: float64
# 0    30463
# 1    12259
# 2     4034
# Name: fips, dtype: int64

# %%
sns.scatterplot(x='logerror',y='taxvaluedollarcnt', data = data, hue = 'fips')

# %%
sns.scatterplot(x ='latitude',y ='longitude', hue = 'fips',data = data)

# %%
sns.scatterplot(x ='logerror',y ='bedroomcnt',data = data, alpha = .3)

# %%
X.corr()
# Out:
#                    latitude  longitude  taxvaluedollarcnt
# latitude           1.000000  -0.531718          -0.175405
# longitude         -0.531718   1.000000           0.003146
# taxvaluedollarcnt -0.175405   0.003146           1.000000

# %%
X.head()
# Out:
#    latitude  longitude  taxvaluedollarcnt
# 1  34449266 -119281531           464000.0
# 2  33886168 -117823170           564778.0
# 3  34245180 -118240722           145143.0
# 4  34145202 -118179824           773303.0
# 5  34149214 -118239357           218552.0

# %%
la_county = data[data.fips == 0].logerror

# %%
orange_county = data[data.fips == 2].logerror

# %%
ventura_county = data[data.fips == 1].logerror

# %%
scipy.stats.ttest_ind(data.logerror, la_county)

# %%
scipy.stats.ttest_ind(data.logerror, orange_county)

# %%
scipy.stats.ttest_ind(data.logerror, ventura_county)

# %%
scipy.stats.ttest_ind(la_county, orange_county)

# %%
scipy.stats.ttest_ind(la_county, ventura_county)

# %%
scipy.stats.ttest_ind(ventura_county, orange_county)

# %% [markdown]
# # Model
