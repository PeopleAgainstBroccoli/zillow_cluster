# %% [markdown]
# # Goals
#
# ### - Identify what is driving log error
# ### - Build a model to accurately predict the log error

# %% [markdown]
# # Hypotheses
# What we think causes log error:
# - Location: certain geographic areas may be harder to accurately predict than others. Log error may differ by County.
# - Price: higher prices may have more variance which makes them harder to predict
# - Age of Property: newer homes may be similarily built, thus easier to predict price. Older property values may have more variance, thus making them harder to predict
# - Amenities: fireplace, pool, hot tub, and garage are nice amenities that not all properties include. These amenities may be driving log error by making property values harder to predict.
# - Data density: geographic areas with more data points (higher data density) will have lower log errors. Geogrphaic areas with less data points (lower data density) will have higher log errors. The more data we have in a given geographic area, the lower we would expect those log errors to be.

# %% [markdown]
# ## Set up Environment

# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set(style="white", palette="muted")
#import acquire
import prep
# %matplotlib inline
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
import scipy

# %% [markdown]
# # Acquire

# %% [markdown]
# ### Here we acquire our data from the SQL database. We have already chosen to filter on the following conditions:
# - Only include properties containing latitude and longitude values.
# - Only include properties with a transaction in 2017 (including the most recent transaction date to avoid duplicates).
# - Only include single unit properties.
#   - Single unit property: a free standing property in which the owner also owns the land beneath the property. A single unit property is built for the use of one family (i.e. does not include duplexes, triplexes, etc.)

# %%
data = pd.read_csv('query_result.csv')

# %% [markdown]
# Preview data:

# %%
data.shape
# Out:
# (52357, 61)

# %%
data.head(5)
# Out:
#    parcelid       id  airconditioningtypeid  architecturalstyletypeid  \
# 0  14297519  1727539                    NaN                       NaN
# 1  17052889  1387261                    NaN                       NaN
# 2  14186244    11677                    NaN                       NaN
# 3  12177905  2288172                    NaN                       NaN
# 4  12095076   781532                    1.0                       NaN
#
#    basementsqft  bathroomcnt  bedroomcnt  buildingclasstypeid  \
# 0           NaN          3.5           4                  NaN
# 1           NaN          1.0           2                  NaN
# 2           NaN          2.0           3                  NaN
# 3           NaN          3.0           4                  NaN
# 4           NaN          3.0           4                  NaN
#
#    buildingqualitytypeid  calculatedbathnbr  ...  structuretaxvaluedollarcnt  \
# 0                    NaN                3.5  ...                    485713.0
# 1                    NaN                1.0  ...                     88000.0
# 2                    NaN                2.0  ...                     85289.0
# 3                    8.0                3.0  ...                    108918.0
# 4                    9.0                3.0  ...                    276684.0
#
#    taxvaluedollarcnt  assessmentyear  landtaxvaluedollarcnt  taxamount  \
# 0          1023282.0            2016               537569.0   11013.72
# 1           464000.0            2016               376000.0    5672.48
# 2           564778.0            2016               479489.0    6488.30
# 3           145143.0            2016                36225.0    1777.51
# 4           773303.0            2016               496619.0    9516.26
#
#    taxdelinquencyflag  taxdelinquencyyear  censustractandblock  logerror  \
# 0                 NaN                 NaN         6.059063e+13  0.025595
# 1                 NaN                 NaN         6.111001e+13  0.055619
# 2                 NaN                 NaN         6.059022e+13  0.005383
# 3                 NaN                 NaN         6.037300e+13 -0.103410
# 4                 NaN                 NaN         6.037461e+13 -0.001011
#
#    transactiondate
# 0       2017-01-01
# 1       2017-01-01
# 2       2017-01-01
# 3       2017-01-01
# 4       2017-01-01
#
# [5 rows x 61 columns]

# %%
data.columns
# Out:
# Index(['parcelid', 'id', 'airconditioningtypeid', 'architecturalstyletypeid',
#        'basementsqft', 'bathroomcnt', 'bedroomcnt', 'buildingclasstypeid',
#        'buildingqualitytypeid', 'calculatedbathnbr', 'decktypeid',
#        'finishedfloor1squarefeet', 'calculatedfinishedsquarefeet',
#        'finishedsquarefeet12', 'finishedsquarefeet13', 'finishedsquarefeet15',
#        'finishedsquarefeet50', 'finishedsquarefeet6', 'fips', 'fireplacecnt',
#        'fullbathcnt', 'garagecarcnt', 'garagetotalsqft', 'hashottuborspa',
#        'heatingorsystemtypeid', 'latitude', 'longitude', 'lotsizesquarefeet',
#        'poolcnt', 'poolsizesum', 'pooltypeid10', 'pooltypeid2', 'pooltypeid7',
#        'propertycountylandusecode', 'propertylandusetypeid',
#        'propertyzoningdesc', 'rawcensustractandblock', 'regionidcity',
#        'regionidcounty', 'regionidneighborhood', 'regionidzip', 'roomcnt',
#        'storytypeid', 'threequarterbathnbr', 'typeconstructiontypeid',
#        'unitcnt', 'yardbuildingsqft17', 'yardbuildingsqft26', 'yearbuilt',
#        'numberofstories', 'fireplaceflag', 'structuretaxvaluedollarcnt',
#        'taxvaluedollarcnt', 'assessmentyear', 'landtaxvaluedollarcnt',
#        'taxamount', 'taxdelinquencyflag', 'taxdelinquencyyear',
#        'censustractandblock', 'logerror', 'transactiondate'],
#       dtype='object')

# %% [markdown]
# # Prepare
# ### There are several rows and columns that are missing data. We need to treat null values by dropping columns, dropping rows, or imputing missing values.

# %% [markdown]
# ### Preview nulls

# %% [markdown]
# This function shows the amount of rows that have null values for each column. We use this to check if there are any columns that are droppable due to a large portion of nulls.

# %%
prep.nulls_by_col(data)
# Out:
#                               num_rows_missing  pct_rows_missing
# parcelid                                     0          0.000000
# id                                           0          0.000000
# airconditioningtypeid                    38738          0.739882
# architecturalstyletypeid                 52287          0.998663
# basementsqft                             52310          0.999102
# bathroomcnt                                  0          0.000000
# bedroomcnt                                   0          0.000000
# buildingclasstypeid                      52357          1.000000
# buildingqualitytypeid                    18692          0.357011
# calculatedbathnbr                          162          0.003094
# decktypeid                               51968          0.992570
# finishedfloor1squarefeet                 47986          0.916515
# calculatedfinishedsquarefeet               107          0.002044
# finishedsquarefeet12                       273          0.005214
# finishedsquarefeet13                     52357          1.000000
# finishedsquarefeet15                     52357          1.000000
# finishedsquarefeet50                     47986          0.916515
# finishedsquarefeet6                      52191          0.996829
# fips                                         0          0.000000
# fireplacecnt                             45124          0.861852
# fullbathcnt                                162          0.003094
# garagecarcnt                             34373          0.656512
# garagetotalsqft                          34373          0.656512
# hashottuborspa                           50843          0.971083
# heatingorsystemtypeid                    18497          0.353286
# latitude                                     0          0.000000
# longitude                                    0          0.000000
# lotsizesquarefeet                          375          0.007162
# poolcnt                                  41277          0.788376
# poolsizesum                              51492          0.983479
# ...                                        ...               ...
# pooltypeid2                              51286          0.979544
# pooltypeid7                              42364          0.809137
# propertycountylandusecode                    0          0.000000
# propertylandusetypeid                        0          0.000000
# propertyzoningdesc                       18559          0.354470
# rawcensustractandblock                       0          0.000000
# regionidcity                              1036          0.019787
# regionidcounty                               0          0.000000
# regionidneighborhood                     33357          0.637107
# regionidzip                                 26          0.000497
# roomcnt                                      0          0.000000
# storytypeid                              52310          0.999102
# threequarterbathnbr                      45640          0.871708
# typeconstructiontypeid                   52281          0.998548
# unitcnt                                  18582          0.354910
# yardbuildingsqft17                       50422          0.963042
# yardbuildingsqft26                       52294          0.998797
# yearbuilt                                  140          0.002674
# numberofstories                          37824          0.722425
# fireplaceflag                            52276          0.998453
# structuretaxvaluedollarcnt                  82          0.001566
# taxvaluedollarcnt                            1          0.000019
# assessmentyear                               0          0.000000
# landtaxvaluedollarcnt                        1          0.000019
# taxamount                                    4          0.000076
# taxdelinquencyflag                       50288          0.960483
# taxdelinquencyyear                       50288          0.960483
# censustractandblock                        125          0.002387
# logerror                                     0          0.000000
# transactiondate                              0          0.000000
#
# [61 rows x 2 columns]

# %% [markdown]
# This function shows the amount of rows that are missing a certain number of columns. We use this to check if there are any rows that are missing so many columns, they are not worth keeping.
# We will drop columns first, and then come back and check these rows to see how they were affected.

# %%
prep.nulls_by_row(data)
# Out:
#    num_cols_missing    pct_cols_missing  num_rows
# 0                19  31.147540983606557         2
# 1                20   32.78688524590164        10
# 2                21   34.42622950819672        83
# 3                22    36.0655737704918       261
# 4                23  37.704918032786885       480
# 5                24   39.34426229508197       534
# 6                25   40.98360655737705      2910
# 7                26   42.62295081967213      5921
# 8                27   44.26229508196721      7934
# 9                28   45.90163934426229     15854
# 10               29  47.540983606557376     12523
# 11               30   49.18032786885246      4405
# 12               31   50.81967213114754      1057
# 13               32  52.459016393442624       227
# 14               33   54.09836065573771        36
# 15               34   55.73770491803278        16
# 16               35  57.377049180327866         8
# 17               36   59.01639344262295        12
# 18               37   60.65573770491803        22
# 19               38  62.295081967213115        51
# 20               39  63.934426229508205         7
# 21               40   65.57377049180327         1
# 22               41   67.21311475409836         1
# 23               42   68.85245901639344         2

# %% [markdown]
# ### Run data through our prep function to acheive the following:
# - fills nulls in taxdelinquencyflag with 'N'
# - fills nulls with zero for fireplacecnt, garagecarcnt, poolcnt, and taxdelinquencyyear
# - drops 28 columns due to excess nulls and irrelevency
# - encodes the fips columns
# - data shape transformed from 52357 rows x 61 columns to 46649 rows x 33 columns

# %%
data = prep.prep_zillow(data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52357 entries, 0 to 52356
# Data columns (total 61 columns):
# parcelid                        52357 non-null int64
# id                              52357 non-null int64
# airconditioningtypeid           13619 non-null float64
# architecturalstyletypeid        70 non-null float64
# basementsqft                    47 non-null float64
# bathroomcnt                     52357 non-null float64
# bedroomcnt                      52357 non-null int64
# buildingclasstypeid             0 non-null float64
# buildingqualitytypeid           33665 non-null float64
# calculatedbathnbr               52195 non-null float64
# decktypeid                      389 non-null float64
# finishedfloor1squarefeet        4371 non-null float64
# calculatedfinishedsquarefeet    52250 non-null float64
# finishedsquarefeet12            52084 non-null float64
# finishedsquarefeet13            0 non-null float64
# finishedsquarefeet15            0 non-null float64
# finishedsquarefeet50            4371 non-null float64
# finishedsquarefeet6             166 non-null float64
# fips                            52357 non-null int64
# fireplacecnt                    7233 non-null float64
# fullbathcnt                     52195 non-null float64
# garagecarcnt                    17984 non-null float64
# garagetotalsqft                 17984 non-null float64
# hashottuborspa                  1514 non-null float64
# heatingorsystemtypeid           33860 non-null float64
# latitude                        52357 non-null int64
# longitude                       52357 non-null int64
# lotsizesquarefeet               51982 non-null float64
# poolcnt                         11080 non-null float64
# poolsizesum                     865 non-null float64
# pooltypeid10                    443 non-null float64
# pooltypeid2                     1071 non-null float64
# pooltypeid7                     9993 non-null float64
# propertycountylandusecode       52357 non-null object
# propertylandusetypeid           52357 non-null int64
# propertyzoningdesc              33798 non-null object
# rawcensustractandblock          52357 non-null float64
# regionidcity                    51321 non-null float64
# regionidcounty                  52357 non-null int64
# regionidneighborhood            19000 non-null float64
# regionidzip                     52331 non-null float64
# roomcnt                         52357 non-null int64
# storytypeid                     47 non-null float64
# threequarterbathnbr             6717 non-null float64
# typeconstructiontypeid          76 non-null float64
# unitcnt                         33775 non-null float64
# yardbuildingsqft17              1935 non-null float64
# yardbuildingsqft26              63 non-null float64
# yearbuilt                       52217 non-null float64
# numberofstories                 14533 non-null float64
# fireplaceflag                   81 non-null float64
# structuretaxvaluedollarcnt      52275 non-null float64
# taxvaluedollarcnt               52356 non-null float64
# assessmentyear                  52357 non-null int64
# landtaxvaluedollarcnt           52356 non-null float64
# taxamount                       52353 non-null float64
# taxdelinquencyflag              2069 non-null object
# taxdelinquencyyear              2069 non-null float64
# censustractandblock             52232 non-null float64
# logerror                        52357 non-null float64
# transactiondate                 52357 non-null object
# dtypes: float64(47), int64(10), object(4)
# memory usage: 24.4+ MB

# %%
data.shape
# Out:
# (46649, 33)

# %%
data.columns
# Out:
# Index(['parcelid', 'id', 'bathroomcnt', 'bedroomcnt',
#        'calculatedfinishedsquarefeet', 'fips', 'fireplacecnt', 'fullbathcnt',
#        'garagecarcnt', 'latitude', 'longitude', 'lotsizesquarefeet', 'poolcnt',
#        'propertycountylandusecode', 'propertylandusetypeid',
#        'rawcensustractandblock', 'regionidcity', 'regionidcounty',
#        'regionidzip', 'roomcnt', 'yearbuilt', 'structuretaxvaluedollarcnt',
#        'taxvaluedollarcnt', 'assessmentyear', 'landtaxvaluedollarcnt',
#        'taxamount', 'taxdelinquencyflag', 'taxdelinquencyyear',
#        'censustractandblock', 'logerror', 'transactiondate', 'poor_people',
#        'log_me'],
#       dtype='object')

# %%
data.dtypes
# Out:
# parcelid                          int64
# id                                int64
# bathroomcnt                     float64
# bedroomcnt                        int64
# calculatedfinishedsquarefeet    float64
# fips                              int64
# fireplacecnt                    float64
# fullbathcnt                     float64
# garagecarcnt                    float64
# latitude                          int64
# longitude                         int64
# lotsizesquarefeet               float64
# poolcnt                         float64
# propertycountylandusecode        object
# propertylandusetypeid             int64
# rawcensustractandblock          float64
# regionidcity                    float64
# regionidcounty                    int64
# regionidzip                     float64
# roomcnt                           int64
# yearbuilt                       float64
# structuretaxvaluedollarcnt      float64
# taxvaluedollarcnt               float64
# assessmentyear                    int64
# landtaxvaluedollarcnt           float64
# taxamount                       float64
# taxdelinquencyflag               object
# taxdelinquencyyear              float64
# censustractandblock             float64
# logerror                        float64
# transactiondate                  object
# poor_people                        bool
# log_me                             bool
# dtype: object

# %%
X = data.drop(columns = ['poor_people', 'log_me', 'transactiondate', 'taxdelinquencyflag', 'propertycountylandusecode'])

# %%
sns.heatmap(X)

# %%
data.head()
# Out:
#    parcelid       id  bathroomcnt  bedroomcnt  calculatedfinishedsquarefeet  \
# 1  17052889  1387261          1.0           2                        1465.0
# 2  14186244    11677          2.0           3                        1243.0
# 3  12177905  2288172          3.0           4                        2376.0
# 4  12095076   781532          3.0           4                        2962.0
# 5  12069064   870991          1.0           2                         738.0
#
#    fips  fireplacecnt  fullbathcnt  garagecarcnt  latitude  ...  \
# 1     2           1.0          1.0           1.0  34449266  ...
# 2     1           0.0          2.0           2.0  33886168  ...
# 3     0           0.0          3.0           0.0  34245180  ...
# 4     0           0.0          3.0           0.0  34145202  ...
# 5     0           0.0          1.0           0.0  34149214  ...
#
#    assessmentyear  landtaxvaluedollarcnt  taxamount taxdelinquencyflag  \
# 1            2016               376000.0    5672.48                  N
# 2            2016               479489.0    6488.30                  N
# 3            2016                36225.0    1777.51                  N
# 4            2016               496619.0    9516.26                  N
# 5            2016               199662.0    2366.08                  N
#
#    taxdelinquencyyear  censustractandblock  logerror  transactiondate  \
# 1                 0.0         6.111001e+13  0.055619       2017-01-01
# 2                 0.0         6.059022e+13  0.005383       2017-01-01
# 3                 0.0         6.037300e+13 -0.103410       2017-01-01
# 4                 0.0         6.037461e+13 -0.001011       2017-01-01
# 5                 0.0         6.037302e+13  0.101723       2017-01-01
#
#    poor_people  log_me
# 1         True    True
# 2         True    True
# 3         True    True
# 4         True    True
# 5         True    True
#
# [5 rows x 33 columns]

# %% [markdown]
# # Explore
# To do:
#
# - Check our hypotheses
# - t tests
# - chi square test
# - clustering

# %%
sns.scatterplot(x='logerror',y='yearbuilt', data = data)

# %%
data.corr()

# %%
sns.scatterplot(x='logerror',y='lotsizesquarefeet', data = data)

# %%
sns.scatterplot(x='logerror',y='calculatedfinishedsquarefeet', data = data, alpha = .3)

# %%
#scipy.stats.ttest_ind(X.logerror,X.calculatedfinishedsquarefeet)
# Out:
# Ttest_indResult(statistic=-530.2735804649802, pvalue=0.0)

# %%
sns.scatterplot(x='logerror',y='taxvaluedollarcnt', data = data)

# %%
sns.scatterplot(x ='latitude',y ='longitude', hue = 'fips',data = data)

# %%
sns.scatterplot(x ='logerror',y ='bedroomcnt',data = data, alpha = .3)

# %%
#sns.scatterplot(x ='logerror',y ='poolcnt',data = data, alpha = .3)

X['count'] = data['poolcnt'] + data['bedroomcnt'] + data['bathroomcnt'] + data['fullbathcnt']

sns.scatterplot(y = 'logerror', x = 'count', data = data)

# %%
X.corr()
# Out:
#                               parcelid        id  bathroomcnt  bedroomcnt  \
# parcelid                      1.000000  0.001808     0.073695    0.082058
# id                            0.001808  1.000000    -0.003845   -0.002038
# bathroomcnt                   0.073695 -0.003845     1.000000    0.619130
# bedroomcnt                    0.082058 -0.002038     0.619130    1.000000
# calculatedfinishedsquarefeet  0.073757 -0.004274     0.804394    0.634939
# fips                          0.543789 -0.011818     0.161128    0.159273
# fireplacecnt                  0.349086 -0.006688     0.160921    0.150341
# fullbathcnt                   0.029129 -0.002979     0.980292    0.607815
# garagecarcnt                  0.458820 -0.006698     0.219946    0.197965
# latitude                     -0.175681 -0.003685     0.050896    0.049266
# longitude                    -0.072366  0.009676     0.003647   -0.008104
# lotsizesquarefeet            -0.014608 -0.005392     0.015709    0.002621
# poolcnt                      -0.008540 -0.001122     0.254358    0.216048
# propertylandusetypeid         0.003084  0.005332    -0.006905   -0.007994
# rawcensustractandblock        0.538252 -0.013420     0.140428    0.147064
# regionidcity                 -0.027704  0.006971    -0.060853   -0.050373
# regionidcounty               -0.398811  0.004728    -0.163218   -0.143140
# regionidzip                   0.029045 -0.003725     0.034153    0.021235
# roomcnt                       0.436515 -0.009112     0.131381    0.201951
# yearbuilt                     0.169325 -0.003441     0.543469    0.374299
# structuretaxvaluedollarcnt    0.094526 -0.006377     0.638853    0.418191
# taxvaluedollarcnt             0.093144 -0.003580     0.402810    0.238513
# assessmentyear                     NaN       NaN          NaN         NaN
# landtaxvaluedollarcnt         0.070176 -0.001146     0.163685    0.073728
# taxamount                     0.050062 -0.004611     0.413839    0.249144
# taxdelinquencyyear           -0.045068 -0.005935    -0.057682   -0.043680
# censustractandblock           0.057150 -0.005095     0.014225    0.019714
# logerror                      0.008268  0.001261     0.025962    0.037229
# count                         0.063775 -0.003236     0.937349    0.818765
#
#                               calculatedfinishedsquarefeet      fips  \
# parcelid                                          0.073757  0.543789
# id                                               -0.004274 -0.011818
# bathroomcnt                                       0.804394  0.161128
# bedroomcnt                                        0.634939  0.159273
# calculatedfinishedsquarefeet                      1.000000  0.162254
# fips                                              0.162254  1.000000
# fireplacecnt                                      0.198865  0.621686
# fullbathcnt                                       0.779245  0.076703
# garagecarcnt                                      0.227273  0.874378
# latitude                                          0.031959 -0.240409
# longitude                                        -0.002387 -0.190980
# lotsizesquarefeet                                 0.025503 -0.017269
# poolcnt                                           0.301471  0.020110
# propertylandusetypeid                            -0.006867  0.006221
# rawcensustractandblock                            0.143708  0.962758
# regionidcity                                     -0.058273 -0.062253
# regionidcounty                                   -0.158600 -0.793324
# regionidzip                                       0.029213  0.054589
# roomcnt                                           0.148603  0.832463
# yearbuilt                                         0.475731  0.327841
# structuretaxvaluedollarcnt                        0.726492  0.185187
# taxvaluedollarcnt                                 0.460558  0.189418
# assessmentyear                                         NaN       NaN
# landtaxvaluedollarcnt                             0.189614  0.143037
# taxamount                                         0.471333  0.107545
# taxdelinquencyyear                               -0.048009 -0.079556
# censustractandblock                               0.013393  0.099698
# logerror                                          0.027148  0.012797
# count                                             0.817326  0.142590
#
#                               fireplacecnt  fullbathcnt  garagecarcnt  \
# parcelid                          0.349086     0.029129      0.458820
# id                               -0.006688    -0.002979     -0.006698
# bathroomcnt                       0.160921     0.980292      0.219946
# bedroomcnt                        0.150341     0.607815      0.197965
# calculatedfinishedsquarefeet      0.198865     0.779245      0.227273
# fips                              0.621686     0.076703      0.874378
# fireplacecnt                      1.000000     0.110773      0.534229
# fullbathcnt                       0.110773     1.000000      0.127037
# garagecarcnt                      0.534229     0.127037      1.000000
# latitude                         -0.066611     0.104012     -0.436511
# longitude                        -0.224359    -0.020822      0.132331
# lotsizesquarefeet                -0.003959     0.018719     -0.019280
# poolcnt                           0.082847     0.254272      0.055237
# propertylandusetypeid             0.003506    -0.007677      0.006385
# rawcensustractandblock            0.635138     0.071242      0.745915
# regionidcity                     -0.027360    -0.055089     -0.070271
# regionidcounty                   -0.410722    -0.069030     -0.909707
# regionidzip                       0.029167     0.028844      0.055712
# roomcnt                           0.619869     0.063872      0.810570
# yearbuilt                         0.202967     0.493759      0.373592
# structuretaxvaluedollarcnt        0.172258     0.609187      0.196200
# taxvaluedollarcnt                 0.165391     0.372125      0.234227
# assessmentyear                         NaN          NaN           NaN
# landtaxvaluedollarcnt             0.118823     0.140321      0.195775
# taxamount                         0.103320     0.391481      0.146939
# taxdelinquencyyear               -0.050643    -0.049424     -0.080392
# censustractandblock               0.066191     0.007164      0.076477
# logerror                          0.000569     0.024042      0.013101
# count                             0.160733     0.933035      0.199382
#
#                               latitude  ...  yearbuilt  \
# parcelid                     -0.175681  ...   0.169325
# id                           -0.003685  ...  -0.003441
# bathroomcnt                   0.050896  ...   0.543469
# bedroomcnt                    0.049266  ...   0.374299
# calculatedfinishedsquarefeet  0.031959  ...   0.475731
# fips                         -0.240409  ...   0.327841
# fireplacecnt                 -0.066611  ...   0.202967
# fullbathcnt                   0.104012  ...   0.493759
# garagecarcnt                 -0.436511  ...   0.373592
# latitude                      1.000000  ...   0.111814
# longitude                    -0.531806  ...   0.078805
# lotsizesquarefeet             0.056032  ...   0.029866
# poolcnt                       0.021409  ...   0.094169
# propertylandusetypeid         0.001042  ...  -0.003192
# rawcensustractandblock       -0.059342  ...   0.290474
# regionidcity                 -0.016891  ...  -0.096257
# regionidcounty                0.572760  ...  -0.324817
# regionidzip                   0.018024  ...   0.063768
# roomcnt                      -0.307248  ...   0.200695
# yearbuilt                     0.111814  ...   1.000000
# structuretaxvaluedollarcnt    0.080229  ...   0.532847
# taxvaluedollarcnt            -0.174972  ...   0.266880
# assessmentyear                     NaN  ...        NaN
# landtaxvaluedollarcnt        -0.277078  ...   0.045318
# taxamount                    -0.087231  ...   0.293974
# taxdelinquencyyear            0.035388  ...  -0.065702
# censustractandblock          -0.009192  ...   0.033134
# logerror                     -0.011846  ...   0.015614
# count                         0.073732  ...   0.503292
#
#                               structuretaxvaluedollarcnt  taxvaluedollarcnt  \
# parcelid                                        0.094526           0.093144
# id                                             -0.006377          -0.003580
# bathroomcnt                                     0.638853           0.402810
# bedroomcnt                                      0.418191           0.238513
# calculatedfinishedsquarefeet                    0.726492           0.460558
# fips                                            0.185187           0.189418
# fireplacecnt                                    0.172258           0.165391
# fullbathcnt                                     0.609187           0.372125
# garagecarcnt                                    0.196200           0.234227
# latitude                                        0.080229          -0.174972
# longitude                                      -0.086555           0.002584
# lotsizesquarefeet                               0.023702          -0.001629
# poolcnt                                         0.252446           0.187362
# propertylandusetypeid                          -0.006564          -0.005145
# rawcensustractandblock                          0.198395           0.157757
# regionidcity                                   -0.042432          -0.005137
# regionidcounty                                 -0.103107          -0.203407
# regionidzip                                     0.030973           0.013389
# roomcnt                                         0.026142           0.115610
# yearbuilt                                       0.532847           0.266880
# structuretaxvaluedollarcnt                      1.000000           0.707164
# taxvaluedollarcnt                               0.707164           1.000000
# assessmentyear                                       NaN                NaN
# landtaxvaluedollarcnt                           0.357246           0.912823
# taxamount                                       0.712700           0.950177
# taxdelinquencyyear                             -0.043026          -0.042148
# censustractandblock                             0.020260           0.021875
# logerror                                       -0.012326          -0.029267
# count                                           0.616075           0.379675
#
#                               assessmentyear  landtaxvaluedollarcnt  \
# parcelid                                 NaN               0.070176
# id                                       NaN              -0.001146
# bathroomcnt                              NaN               0.163685
# bedroomcnt                               NaN               0.073728
# calculatedfinishedsquarefeet             NaN               0.189614
# fips                                     NaN               0.143037
# fireplacecnt                             NaN               0.118823
# fullbathcnt                              NaN               0.140321
# garagecarcnt                             NaN               0.195775
# latitude                                 NaN              -0.277078
# longitude                                NaN               0.053281
# lotsizesquarefeet                        NaN              -0.015797
# poolcnt                                  NaN               0.101777
# propertylandusetypeid                    NaN              -0.003004
# rawcensustractandblock                   NaN               0.093672
# regionidcity                             NaN               0.017567
# regionidcounty                           NaN              -0.208796
# regionidzip                              NaN              -0.000209
# roomcnt                                  NaN               0.137245
# yearbuilt                                NaN               0.045318
# structuretaxvaluedollarcnt               NaN               0.357246
# taxvaluedollarcnt                        NaN               0.912823
# assessmentyear                           NaN                    NaN
# landtaxvaluedollarcnt                    NaN               1.000000
# taxamount                                NaN               0.844413
# taxdelinquencyyear                       NaN              -0.030975
# censustractandblock                      NaN               0.017186
# logerror                                 NaN              -0.031759
# count                                    NaN               0.146193
#
#                               taxamount  taxdelinquencyyear  \
# parcelid                       0.050062           -0.045068
# id                            -0.004611           -0.005935
# bathroomcnt                    0.413839           -0.057682
# bedroomcnt                     0.249144           -0.043680
# calculatedfinishedsquarefeet   0.471333           -0.048009
# fips                           0.107545           -0.079556
# fireplacecnt                   0.103320           -0.050643
# fullbathcnt                    0.391481           -0.049424
# garagecarcnt                   0.146939           -0.080392
# latitude                      -0.087231            0.035388
# longitude                     -0.014449            0.004744
# lotsizesquarefeet             -0.001931           -0.000663
# poolcnt                        0.175542           -0.019004
# propertylandusetypeid         -0.006413            0.001838
# rawcensustractandblock         0.088480           -0.071036
# regionidcity                  -0.014839            0.005409
# regionidcounty                -0.118530            0.075472
# regionidzip                    0.012181           -0.007370
# roomcnt                        0.031205           -0.070485
# yearbuilt                      0.293974           -0.065702
# structuretaxvaluedollarcnt     0.712700           -0.043026
# taxvaluedollarcnt              0.950177           -0.042148
# assessmentyear                      NaN                 NaN
# landtaxvaluedollarcnt          0.844413           -0.030975
# taxamount                      1.000000           -0.030105
# taxdelinquencyyear            -0.030105            1.000000
# censustractandblock            0.013662           -0.008501
# logerror                      -0.029348            0.020034
# count                          0.391912           -0.055345
#
#                               censustractandblock  logerror     count
# parcelid                                 0.057150  0.008268  0.063775
# id                                      -0.005095  0.001261 -0.003236
# bathroomcnt                              0.014225  0.025962  0.937349
# bedroomcnt                               0.019714  0.037229  0.818765
# calculatedfinishedsquarefeet             0.013393  0.027148  0.817326
# fips                                     0.099698  0.012797  0.142590
# fireplacecnt                             0.066191  0.000569  0.160733
# fullbathcnt                              0.007164  0.024042  0.933035
# garagecarcnt                             0.076477  0.013101  0.199382
# latitude                                -0.009192 -0.011846  0.073732
# longitude                               -0.040926  0.013959 -0.008478
# lotsizesquarefeet                       -0.001473  0.008767  0.013835
# poolcnt                                 -0.001209 -0.036973  0.413056
# propertylandusetypeid                    0.000607 -0.003986 -0.007161
# rawcensustractandblock                   0.104144  0.009081  0.127382
# regionidcity                            -0.007192  0.004333 -0.062539
# regionidcounty                          -0.060781 -0.017681 -0.137743
# regionidzip                              0.004496  0.001026  0.032275
# roomcnt                                  0.076828  0.014548  0.154000
# yearbuilt                                0.033134  0.015614  0.503292
# structuretaxvaluedollarcnt               0.020260 -0.012326  0.616075
# taxvaluedollarcnt                        0.021875 -0.029267  0.379675
# assessmentyear                                NaN       NaN       NaN
# landtaxvaluedollarcnt                    0.017186 -0.031759  0.146193
# taxamount                                0.013662 -0.029348  0.391912
# taxdelinquencyyear                      -0.008501  0.020034 -0.055345
# censustractandblock                      1.000000  0.008236  0.014333
# logerror                                 0.008236  1.000000  0.024661
# count                                    0.014333  0.024661  1.000000
#
# [29 rows x 29 columns]

# %%
X.head()
# Out:
#    parcelid       id  bathroomcnt  bedroomcnt  calculatedfinishedsquarefeet  \
# 1  17052889  1387261          1.0           2                        1465.0
# 2  14186244    11677          2.0           3                        1243.0
# 3  12177905  2288172          3.0           4                        2376.0
# 4  12095076   781532          3.0           4                        2962.0
# 5  12069064   870991          1.0           2                         738.0
#
#    fips  fireplacecnt  fullbathcnt  garagecarcnt  latitude  ...  roomcnt  \
# 1     2           1.0          1.0           1.0  34449266  ...        5
# 2     1           0.0          2.0           2.0  33886168  ...        6
# 3     0           0.0          3.0           0.0  34245180  ...        0
# 4     0           0.0          3.0           0.0  34145202  ...        0
# 5     0           0.0          1.0           0.0  34149214  ...        0
#
#    yearbuilt  structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# 1     1967.0                     88000.0           464000.0            2016
# 2     1962.0                     85289.0           564778.0            2016
# 3     1970.0                    108918.0           145143.0            2016
# 4     1950.0                    276684.0           773303.0            2016
# 5     1922.0                     18890.0           218552.0            2016
#
#    landtaxvaluedollarcnt  taxamount  taxdelinquencyyear  censustractandblock  \
# 1               376000.0    5672.48                 0.0         6.111001e+13
# 2               479489.0    6488.30                 0.0         6.059022e+13
# 3                36225.0    1777.51                 0.0         6.037300e+13
# 4               496619.0    9516.26                 0.0         6.037461e+13
# 5               199662.0    2366.08                 0.0         6.037302e+13
#
#    logerror
# 1  0.055619
# 2  0.005383
# 3 -0.103410
# 4 -0.001011
# 5  0.101723
#
# [5 rows x 28 columns]

# %%
la_county = data[data.fips == 0].logerror

# %%
orange_county = data[data.fips == 2].logerror

# %%
ventura_county = data[data.fips == 1].logerror

# %%
scipy.stats.ttest_ind(data.logerror, la_county)
# Out:
# Ttest_indResult(statistic=1.5973051127849067, pvalue=0.11020181214988374)

# %%
scipy.stats.ttest_ind(data.logerror, orange_county)
# Out:
# Ttest_indResult(statistic=-0.2504203473645629, pvalue=0.8022633113178469)

# %%
scipy.stats.ttest_ind(data.logerror, ventura_county)
# Out:
# Ttest_indResult(statistic=-2.9310364842462535, pvalue=0.0033796293952714205)

# %%
scipy.stats.ttest_ind(la_county, orange_county)
# Out:
# Ttest_indResult(statistic=-0.920766667691121, pvalue=0.35717871361083264)

# %%
scipy.stats.ttest_ind(la_county, ventura_county)
# Out:
# Ttest_indResult(statistic=-3.7609466053203047, pvalue=0.0001694977269250323)

# %%
scipy.stats.ttest_ind(ventura_county, orange_county)
# Out:
# Ttest_indResult(statistic=1.6500190878959606, pvalue=0.09895837309351971)
